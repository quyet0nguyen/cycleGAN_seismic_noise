# %%
import main

# %%
# !python3 main.py
# Out:
# /home/sohoa1/quyetnv28/cycleGAN_seismic_noise/residual_model.py:99: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data, 0.0, 0.02)
# ...
#  21%|████████▋                                | 192/900 [01:13<04:34,  2.58it/s]d_real_loss: 0.17361105978488922  d_seismic_loss: 0.09203675389289856  d_noise_loss: 0.08157430589199066  d_fake_loss: 0.04837409406900406  g_loss: 11069720.52505643
# ...
# ...
#  23%|█████████▎                               | 205/900 [01:19<04:29,  2.58it/s]
